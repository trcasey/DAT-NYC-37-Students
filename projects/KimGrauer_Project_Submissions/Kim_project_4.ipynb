# %% [markdown]
# # Project 4
#
# In this project, you will summarize and present your analysis from Projects 1-3.

# %% [markdown]
# ### Intro: Write a problem Statement/ Specific Aim for this project

# %% [markdown]
# Answer: Using data from UCLA grduate school admissions, we aim to understand predictors of whether or not someone will be admitted.

# %% [markdown]
# ### Dataset:  Write up a description of your data and any cleaning that was completed

# %% [markdown]
# Answer: The data was in a CSV format and was imported to iPython. Preliminary data exploration found that there were some missing values. I decied to drop these values, althought you could also replace the missing values with the median for that group.
#
# Prestige could be turned into a dummy variable, because we cannot assume that going from each prestige score holds an equal value.

# %% [markdown]
# ### Demo: Provide a table that explains the data by admission status

# %% [markdown]
# Mean (STD) or counts by admission status for each variable
#
# | Not Admitted | Admitted
# ---| ---|---
# GPA | mean(std)  | mean(std)
# GRE |mean(std) | mean(std)
# Prestige 1 | frequency (%) | frequency (%)
# Prestige 2 | frequency (%) | frequency (%)
# Prestige 3 |frequency (%) | frequency (%)
# Prestige 4 |frequency (%) | frequency (%)

# %% [markdown]
# ### Methods: Write up the methods used in your analysis

# %% [markdown]
# Answer: After importing and cleaning the data, I started exploratory analysis. This involved creating visualizations (box plots) and testing if the data behaved normally. I first calculated odds ratios. I then ran a train-test split and a logistic regression using admit as the target variable and GRE, GPA and prestige dummies as the features.
#
# We then analyzed the classifier variable by recreating the dataset with every logical combination of input variables. This was used to test how the variables change as feature inputs change.

# %% [markdown]
# ### Results: Write up your results

# %% [markdown]
# Answer: I found an inverse relationship between prestige and the probability of getting admitted to UCLA. This makes sense, however, because prestige 1 is the most prestigious, so the more prestigious university you attend, the more likely you are to get into a UCLA graduate program.
#
# We can also interpret the odds ratio for each variable below:
#
# gre           1.002267
# gpa           2.234545
# prestige_2    0.508931
# prestige_3    0.261792
# prestige_4    0.211938
# intercept     0.018500
# dtype: float64
#
# Prestige confirms again what was said above, as you go to a less presitigous school, your the likelihood that you get admitted goes down.

# %% [markdown]
# ### Visuals: Provide a table or visualization of these results

# %%
cd
# Out:
# /Users/kimberlygrauer

# %% [markdown]
# <img src='placeholder.png' height= 25% width= 25%>
# from IPython.display import Image
# Image(filename='Desktop/image_1.png')

# %%
from IPython.display import Image
Image(filename='Desktop/image_1.png')

# %%
from IPython.display import Image
Image(filename='Desktop/image_2.png')

# %% [markdown]
# <img src='placeholder.png' height= 25% width= 25%>

# %% [markdown]
# ### Discussion: Write up your discussion and future steps

# %% [markdown]
# Answer: This final graph shows how each of the featues affects the likelihood of getting admitted. What we can see is your likelihood of getting amitted goes up as your GRE and GPA go up. But there is also this additional influence of prestige, which shifts your likeihood of getting admitted up irregardless of gre and gpa. An individual with the same GPA or GRE from all differnet classes of prestige has different chances of getting admaitted to UCLA.
#
# In this project, there is a future opportunity to introduce more features into the analysis. Maybe prestige, for example, is measuring something else, such as family income. Then family income would actually be a better predictor.
