# %% [markdown]
# # Project 1
#
# In this first project you will create a framework to scope out data science projects. This framework will provide you with a guide to develop a well-articulated problem statement and analysis plan that will be robust and reproducible.

# %% [markdown]
# ### Read and evaluate the following problem statement:
# Determine which free-tier customers will covert to paying customers, using demographic data collected at signup (age, gender, location, and profession) and customer useage data (days since last log in, and activity score `1 = active user`, `0 = inactive user`) based on Hooli data from Jan-Apr 2015.

# %% [markdown]
# #### 1. What is the outcome?

# %% [markdown]
# Answer: The outcome is the prediction of which free-tier customers will convert to paying customers.

# %% [markdown]
# #### 2. What are the predictors/covariates?

# %% [markdown]
# Answer: The predictors/covariates include demographic data (age, gender, location, and profession), as well as customer usage data (days since last log in and an activity score)

# %% [markdown]
# #### 3. What timeframe is this data relevant for?

# %% [markdown]
# Answer: Jan-Apr 2015

# %% [markdown]
# #### 4. What is the hypothesis?

# %% [markdown]
# Answer: The hypothesis could be that free-tier active users are likely to become paying customers.

# %% [markdown]
# ## Let's get started with our dataset

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
import seaborn as sns

# %matplotlib inline
plt.style.use('ggplot')

# If you checked-out the GitHub repository, the UCLA dataset is under ../assets/admissions.csv (relative to this file)
path = os.path.join('..', 'assets', 'admissions.csv')

"""""
# Alternative: Get the dataset directly online...
path = 'http://github.com/ga-students/sf-dat-21/raw/master/unit-projects/dataset/admissions.csv'
"""""

df = pd.read_csv(path)

df.head()
# Out:
#    admit    gre   gpa  prestige
# 0      0  380.0  3.61       3.0
# 1      1  660.0  3.67       3.0
# 2      1  800.0  4.00       1.0
# 3      1  640.0  3.19       4.0
# 4      0  520.0  2.93       4.0

# %% [markdown]
# #### 1. Create a data dictionary

# %% [markdown]
# Answer:
#
# Variable | Description | Type of Variable
# ---| ---| ---
# Admit | Admission into Grad School | categorical
# Prestige | Prestige of university (1-4) | categorical
# GPA | Undergrad GPA (4.0 scale) | continuous
# GRE | GRE score | continuous

# %% [markdown]
# We would like to explore the association between X and Y

# %% [markdown]
# #### 2. What is the outcome?

# %% [markdown]
# Answer: The outcome is admittance into university.

# %% [markdown]
# #### 3. What are the predictors/covariates?

# %% [markdown]
# Answer: The predictors/covariates are the variables gre score, gpa, and prestige.

# %% [markdown]
# #### 4. What timeframe is this data relevant for?

# %% [markdown]
# Answer: It is not relevant, it is cross-sectional data

# %% [markdown]
# #### 4. What is the hypothesis?

# %% [markdown]
# Answer: The variables gre score, gpa, and prestige are positively correlated with admission into graduate school.

# %% [markdown]
#     Using the above information, write a well-formed problem statement.

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# ### Exploratory Analysis Plan

# %% [markdown]
# Using the lab from a class as a guide, create an exploratory analysis plan.

# %% [markdown]
# #### 1. What are the goals of the exploratory analysis?

# %% [markdown]
# Answer: to assess summary statistics, and potentially test the statistical significance of predictors in a multivariate regression.

# %% [markdown]
# #### 2a. What are the assumptions of the distribution of data?

# %% [markdown]
# Answer: the assumption is that the data is normally distributed.

# %% [markdown]
# #### 2b. How will you determine the distribution of your data?

# %% [markdown]
# Answer: By assesseing summary statistics, mean and median.

# %% [markdown]
# #### 3a. How might outliers impact your analysis?

# %% [markdown]
# Answer: Outliers may skew the mean.

# %% [markdown]
# #### 3b. How will you test for outliers?

# %% [markdown]
# Answer: I could plot the data to visually see outliers in a swarmplot.

# %%
plt = sns.swarmplot("admit", "gre", data=df);

# %%
plt = sns.swarmplot("admit", "prestige", data=df);

# %%
plt = sns.swarmplot("admit", "gpa", data=df);

# %% [markdown]
# #### 4a. What is collinearity?

# %% [markdown]
# Answer: When two or more predictive variables are highly correlated with each other.

# %% [markdown]
# #### 4b. How will you test for collinearity?

# %% [markdown]
# Answer: I could execute a correlation matrix.

# %%
plt.figure(figsize=(10, 10))

sns.heatmap(df.corr())

# %% [markdown]
# #### 5. What is your exploratory analysis plan?
# Using the above information, write an exploratory analysis plan that would allow you or a colleague to reproduce your analysis one year from now.

# %% [markdown]
# Answer:
# 1. Assess summary statistics
# 2. Assess correlation
# 3. Assess outliers

# %% [markdown]
# ## Bonus Questions:
# 1. Outline your analysis method for predicting your outcome
# 2. Write an alternative problem statement for your dataset
# 3. Articulate the assumptions and risks of the alternative model
