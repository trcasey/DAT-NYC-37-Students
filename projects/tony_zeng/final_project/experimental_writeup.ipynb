# %% [markdown]
# # Project Design Writeup and Approval Template
#
# Follow this as a guide to completing the project design writeup. The questions for each section are merely there to suggest what the baseline should cover; be sure to use detail as it will make the project much easier to approach as the class moves on.
#
# ### Project Problem and Hypothesis
# * What's the project about? What problem are you solving?
#
# The project is about predicting whether a news article has a positive or negative indication of the US economy.
# * Where does this seem to reside as a machine learning problem? Are you predicting some continuous number, or predicting a binary value?
#
# This project will revolve around reading certain keywords from the news article title and summary to predict the impact it have on the US economy. This will be a continuous number: 1-9 (9 - positive, 1 - negative)
# * What kind of impact do you think it could have?
#
# I think readers will have a better understanding of the US economy and what type of events impact the economy positively and negatively.
# * What do you think will have the most impact in predicting the value you are interested in solving for?
#
# I think the ranking of the news article from a scale of 0-9 and the keywords are associated with each ranking.
#
# ### Datasets
# * Description of data set available, at the field level (see table)
#
# The data set have 5000 rows with article headline and a short, bolded excerpt of a sentence or two from the artcile. The dataset also provide whether the sentence provide a indication of the US economy's health, then rated the indication on a scale 1-9. with 1 being being negative and 9 being positive.
#
# Data Fields:
# _unit_id,
# _golden,
# _unit_state,
# _trusted_judgments,
# _last_judgment_at,positivity,
# positivity:confidence,
# relevance,
# relevance:confidence,
# orig__golden,
# articleid,
# date,headline,
# lineid,next_sentence,
# positivity_gold,p
# revious_sentence,
# relevance_gold,text
#
# Sample Data:
# _unit_id,_golden,_unit_state,_trusted_judgments,_last_judgment_at,positivity,positivity:confidence,relevance,relevance:confidence,orig__golden,articleid,date,headline,lineid,next_sentence,positivity_gold,previous_sentence,relevance_gold,text
# 729487630,FALSE,finalized,3,6/8/15 14:26,,0,not sure,0.3469,,109092213,2/23/93,"Nasdaq Index Falls 1.7% But Dow Stocks Are Up: Nasdaq Index Falls 1.7%, But Dow Stocks Move Higher",109092213_01,"The Nasdaq composite index, home of technology companies large and small, fell 1.7 percent even as the Dow Jones industrial average rose 20.81 points, to 3,342.99.",,,,The stock market accelerated its screeching swerve away from Nasdaq stocks yesterday as investors piled into the Dow industrials and utilities.
# 729487631,FALSE,finalized,3,6/11/15 10:58,6,0.3675,yes,1,,109092213,2/23/93,"Nasdaq Index Falls 1.7% But Dow Stocks Are Up: Nasdaq Index Falls 1.7%, But Dow Stocks Move Higher",109092213_02,"The bond market continued to rally, propelling (he normally placid ,' Dow Jones utility average to a gain of 6.01	points, or 2.5,6 percent, to 240.61 ‰ÛÓ the best one-day.advance, in percentage terms, in nearly five years. The yield on the 30-year Treasury bond fell to another record low. (Page ‰Û¢ D18.J",,The stock market accelerated its screeching swerve away from Nasdaq stocks yesterday as investors piled into the Dow industrials and utilities.,,"The Nasdaq composite index, home of technology companies large and small, fell 1.7 percent even as the Dow Jones industrial average rose 20.81 points, to 3,342.99."
# 729487632,FALSE,finalized,3,6/6/15 0:15,5,0.3416,yes,0.6771,,109092213,2/23/93,"Nasdaq Index Falls 1.7% But Dow Stocks Are Up: Nasdaq Index Falls 1.7%, But Dow Stocks Move Higher",109092213_03,"The Nasdaq market was stricken by the collapse of Synergen, a biotechnology company that lost more than tWo-thirds of its value after reporting discouraging test results for its most promising drug. With investors already fearing that the Clinton Administration will impose tight controls on health-care costs, the selloff of the whole biotech industry intensified. Some of Nasdaq‰Ûªs leading computer issues, which have been institutional favorites, pulled back as well.",,"The Nasdaq composite index, home of technology companies large and small, fell 1.7 percent even as the Dow Jones industrial average rose 20.81 points, to 3,342.99.",,"The bond market continued to rally, propelling (he normally placid ,' Dow Jones utility average to a gain of 6.01	points, or 2.5,6 percent, to 240.61 ‰ÛÓ the best one-day.advance, in percentage terms, in nearly five years. The yield on the 30-year Treasury bond fell to another record low. (Page ‰Û¢ D18.J"
#
# * If from an API, include a sample return (this is usually included in API documentation!) (if doing this in markdown, use the javacription code tag)
#
# ### Domain knowledge
# * What experience do you already have around this area?
#
# I work in the financial industry and have a good understanding of the US economy.
# * Does it relate or help inform the project in any way?
#
# It will helps validate the accuracy of the model and whether the ranking of the indication is correct.
# * What other research efforts exist?
#     * Use a quick Google search to see what approaches others have made, or talk with your colleagues if it is work related about previous attempts at similar problems.
#
# This dataset is from crowdflower.com and most likely had been analyzed by other data scientists. However, I am unable to find any of these approaches from the site.
#
#     * This could even just be something like "the marketing team put together a forecast in excel that doesn't do well."
#     * Include a benchmark, how other models have performed, even if you are unsure what the metric means.
#
# ### Project Concerns
# * What questions do you have about your project? What are you not sure you quite yet understand? (The more honest you are about this, the easier your instructors can help).
#
# I want to publish my model online similar to this site (http://votelikeyoutweet.com). Users should be able to import a news article headline and the web app will output the positively ranking. However, this might be far fetch as I still need to start my model analysis.
#
# * What are the assumptions and caveats to the problem?
#
# The dataset rankings are correct.
#
#     * What data do you not have access to but wish you had?
#
# The dataset only contains 5000 rows. I would like to use a large dataset.
#
#     * What is already implied about the observations in your data set? For example, if your primary data set is twitter data, it may not be representative of the whole sample (say, predicting who would win an election)
#
# The datasets contains 5000 rows which is a small sample.
#
# * What are the risks to the project?
#     * What's the cost of your model being wrong? (What's the benefit of your model being right?)
#
# If the model is correct it will help readers understand what positively impacts the US economy. If it is wrong it will give a wrong indication.
#     * Is any of the data incorrect? Could it be incorrect?
# N/A
#
# ### Outcomes
# * What do you expect the output to look like?
#
# Certain keywords and phrases used in the news article will have a positive indication of the US economy.
#
# * What does your target audience expect the output to look like?
#
# Provide a accurate model indicating whether an article has a positive or negative impact on the US economy.
#
# * What gain do you expect from your most important feature on its own?
#
# Cleaning the data, fitting the data, and choosing a model that best fits the dataset.
#
# * How complicated does your model have to be?
#
# I don't think the model would be complicated. The model should be similar to what we have been doing in class.
#
# * How successful does your project have to be in order to be considered a "success"?
#
# As long as it provide an accurate model of what I'm trying to predict I will be satisfied.
#
# * What will you do if the project is a bust (this happens! but it shouldn't here)?
#
# Learn from it and look at what went wrong and improve!
